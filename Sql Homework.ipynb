# %%
 # %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine
import psycopg2

engine = create_engine('postgres://postgres:oklahoma@localhost:5432/sqlhomework')
connection = engine.connect()

# %%
import pandas as pd
sql = 'select title, avg(salary) from titles as t inner join salaries as s on t.emp_no=s.emp_no group by title'
avgsalary = pd.read_sql(sql, connection)
avgsalary
# Out:
#                 title           avg
# 0  Assistant Engineer  48493.204786
# 1            Engineer  48539.781423
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.751806
# 4        Senior Staff  58503.286614
# 5               Staff  58465.271904
# 6    Technique Leader  48580.505772

# %%
avgsalary.set_index('title', inplace=True)
avgsalary.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">
